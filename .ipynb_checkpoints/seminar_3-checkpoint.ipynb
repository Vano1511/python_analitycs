# %%
import pandas as pd

# %%
df = pd.read_csv("./laptop_price.csv", encoding="latin-1")
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df["Cpu_company"] = df["Cpu"].apply(lambda x: x.split()[0])
df["Cpu_company"].head(15)
# Out:
# 0     Intel
# 1     Intel
# 2     Intel
# 3     Intel
# 4     Intel
# 5       AMD
# 6     Intel
# 7     Intel
# 8     Intel
# 9     Intel
# 10    Intel
# 11    Intel
# 12    Intel
# 13    Intel
# 14    Intel
# Name: Cpu_company, dtype: object

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_company Memory_amount
# 0      1339.69       Intel             1
# 1       898.94       Intel             1
# 2       575.00       Intel             2
# 3      2537.45       Intel             5
# 4      1803.60       Intel             2

# %%
def repack_memory_in_gb(string: str) -> int:
    list_string = string.split()
    return_list = []
    for el in list_string:
        if el.endswith("TB"):
            return_list.append(int(float(el[:-2]) * 1024))
        elif el.endswith("GB"):
            return_list.append(int(float(el[:-2])))
    return sum(return_list)
    
df["Memory_amount"] = df["Memory"].apply(repack_memory_in_gb)
df.sample(10)
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 958         972    Dell                            XPS 13  Ultrabook    13.3
# 426         433    Dell                     Inspiron 5570   Notebook    15.6
# 783         792  Lenovo                 IdeaPad 110-15IBR   Notebook    15.6
# 653         661     MSI                        GL62M 7REX     Gaming    15.6
# 993        1007  Lenovo                     ThinkPad T560   Notebook    15.6
# 1045       1059      HP                     EliteBook 850   Notebook    15.6
# 1212       1230     MSI                    GS73VR Stealth     Gaming    17.3
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 853         864  Lenovo                    ThinkPad T470p  Ultrabook    14.0
# 467         474    Dell                     Inspiron 5570   Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 958            Quad HD+ 3200x1800            Intel Core i7 6500U 2.5GHz   8GB
# 426             Full HD 1920x1080            Intel Core i7 8550U 1.8GHz   8GB
# 783                      1366x768  Intel Celeron Quad Core N3710 1.6GHz   8GB
# 653             Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz   8GB
# 993             Full HD 1920x1080            Intel Core i5 6200U 2.3GHz   8GB
# 1045            Full HD 1920x1080            Intel Core i5 6300U 2.4GHz   8GB
# 1212  IPS Panel Full HD 1920x1080           Intel Core i7 6700HQ 2.6GHz  16GB
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 853   IPS Panel Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz   8GB
# 467             Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
#
#                       Memory                         Gpu       OpSys  Weight  \
# 958                256GB SSD       Intel HD Graphics 520  Windows 10   1.3kg
# 426     256GB SSD +  2TB HDD              AMD Radeon 530  Windows 10  2.02kg
# 783                  1TB HDD       Intel HD Graphics 405       No OS   2.2kg
# 653     128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10   2.2kg
# 993                256GB SSD       Intel HD Graphics 520  Windows 10   2.3kg
# 1045  256GB SSD +  500GB HDD       Intel HD Graphics 520  Windows 10  1.84kg
# 1212    256GB SSD +  1TB HDD     Nvidia GeForce GTX 1060  Windows 10  2.43kg
# 1215                32GB SSD           Intel HD Graphics   Chrome OS   1.3kg
# 853                256GB SSD     Nvidia GeForce GT 940MX  Windows 10  1.96kg
# 467                  2TB HDD              AMD Radeon 530  Windows 10  2.02kg
#
#       Price_euros  Memory_amount
# 958       1268.00            256
# 426       1142.40           2304
# 783        329.00           1024
# 653       1191.80           1152
# 993       1349.00            256
# 1045      2103.34            756
# 1212      1948.99           1280
# 1215       174.00             32
# 853       1903.00            256
# 467        759.00           2048

# %%
df = df.drop(columns=["Memory_amount", "ScreenResolution"])
df.sample(10)
# Out:
#       laptop_ID Company                                Product  \
# 103         106      HP                         Envy 13-ad009n
# 1258       1276  Lenovo     B51-80 (i7-6500U/8GB/1008GB/Radeon
# 505         512  Lenovo                            ThinkPad 13
# 287         292    Asus                           VivoBook S15
# 980         994    Dell                          Inspiron 7579
# 1029       1043      HP                            Probook 470
# 917         931     MSI                             GE72VR 6RF
# 703         711  Lenovo  V310-15IKB (i5-7200U/4GB/1TB/FHD/W10)
# 1232       1250    Dell                          Inspiron 3567
# 845         855    Dell                            Vostro 3568
#
#                 TypeName  Inches                          Cpu   Ram  \
# 103            Ultrabook    13.3   Intel Core i7 7500U 2.7GHz   8GB
# 1258            Notebook    15.6   Intel Core i7 6500U 2.5GHz   8GB
# 505             Notebook    13.3   Intel Core i5 7200U 2.5GHz   8GB
# 287            Ultrabook    15.6   Intel Core i5 7200U 2.5GHz   8GB
# 980   2 in 1 Convertible    15.6   Intel Core i7 7500U 2.7GHz  12GB
# 1029            Notebook    17.3   Intel Core i5 7200U 2.5GHz   8GB
# 917               Gaming    17.3  Intel Core i7 7700HQ 2.8GHz  16GB
# 703             Notebook    15.6   Intel Core i5 7200U 2.5GHz   4GB
# 1232            Notebook    15.6   Intel Core i3 7100U 2.4GHz   8GB
# 845             Notebook    15.6   Intel Core i7 7500U 2.7GHz   4GB
#
#                     Memory                         Gpu       OpSys  Weight  \
# 103              256GB SSD        Nvidia GeForce MX150  Windows 10  1.38kg
# 1258          1.0TB Hybrid          AMD Radeon R5 M330   Windows 7  2.32kg
# 505              256GB SSD       Intel HD Graphics 620  Windows 10  1.44kg
# 287              256GB SSD        Nvidia GeForce 940MX  Windows 10   1.7kg
# 980              512GB SSD       Intel HD Graphics 620  Windows 10  2.19kg
# 1029             256GB SSD        Nvidia GeForce 930MX  Windows 10  2.63kg
# 917   256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti  Windows 10   2.7kg
# 703     1TB HDD +  1TB HDD       Intel HD Graphics 620  Windows 10   2.1kg
# 1232               1TB HDD       Intel HD Graphics 620  Windows 10   2.3kg
# 845              256GB SSD          AMD Radeon R5 M420  Windows 10  2.18kg
#
#       Price_euros Cpu_company
# 103       1119.00       Intel
# 1258       895.00       Intel
# 505        949.00       Intel
# 287        977.00       Intel
# 980       1299.00       Intel
# 1029      1080.00       Intel
# 917       1599.00       Intel
# 703        621.45       Intel
# 1232       469.01       Intel
# 845        739.00       Intel

# %%
df["SSD"] = 0
df.sample(10)
# Out:
#       laptop_ID Company                                Product   TypeName  \
# 32           33      HP   17-ak001nv (A6-9220/4GB/500GB/Radeon   Notebook
# 766         775    Asus    X751NV-TY001 (N4200/4GB/1TB/GeForce   Notebook
# 790         799    Asus      FX502VM-DM560T (i7-7700HQ/8GB/1TB     Gaming
# 1254       1272    Dell                          Inspiron 3552   Notebook
# 1111       1126    Dell                            Vostro 3559   Notebook
# 8             9    Asus                        ZenBook UX430UN  Ultrabook
# 527         534  Lenovo                      IdeaPad 320-15ISK   Notebook
# 1234       1252   Apple                            MacBook Air  Ultrabook
# 501         508      HP  15-BS026nv (i5-7200U/8GB/256GB/Radeon   Notebook
# 1110       1125      HP                         EliteBook 1030   Notebook
#
#       Inches                  ScreenResolution  \
# 32      17.3                 Full HD 1920x1080
# 766     17.3                          1366x768
# 790     15.6                 Full HD 1920x1080
# 1254    15.6                          1366x768
# 1111    15.6                          1366x768
# 8       14.0                 Full HD 1920x1080
# 527     15.6                          1366x768
# 1234    11.6                          1366x768
# 501     15.6                          1366x768
# 1110    13.3  Quad HD+ / Touchscreen 3200x1800
#
#                                        Cpu   Ram                Memory  \
# 32               AMD A6-Series 9220 2.5GHz   4GB             500GB HDD
# 766   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 790            Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 1254  Intel Pentium Quad Core N3700 1.6GHz   4GB             500GB HDD
# 1111            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 8               Intel Core i7 8550U 1.8GHz  16GB             512GB SSD
# 527               Intel Core i3 6006U 2GHz   8GB               2TB HDD
# 1234                  Intel Core i5 1.6GHz   4GB   256GB Flash Storage
# 501             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1110              Intel Core M 6Y54 1.1GHz   8GB             256GB SSD
#
#                          Gpu       OpSys  Weight  Price_euros  Memory_amount  \
# 32            AMD Radeon 530  Windows 10  2.71kg       439.00            500
# 766     Nvidia GeForce 920MX  Windows 10   2.8kg       470.34           1024
# 790   Nvidia GeForce GTX1060  Windows 10  2.24kg      1339.00           1152
# 1254       Intel HD Graphics  Windows 10   2.2kg       443.99            500
# 1111      AMD Radeon R5 M315   Windows 7  2.24kg       769.15            500
# 8       Nvidia GeForce MX150  Windows 10   1.3kg      1495.00            512
# 527    Nvidia GeForce 920MX        No OS   2.2kg       459.00           2048
# 1234  Intel HD Graphics 6000    Mac OS X  1.08kg       959.00            256
# 501           AMD Radeon 520  Windows 10  1.91kg       618.99            256
# 1110   Intel HD Graphics 515  Windows 10  1.16kg      1699.00            256
#
#       SSD
# 32      0
# 766     0
# 790     0
# 1254    0
# 1111    0
# 8       0
# 527     0
# 1234    0
# 501     0
# 1110    0

# %%
# def ssd_finder(s):
#     if "SSD" in s[1]:
#         return 1
#     else:
#         return 0
df.loc[(df["Memory"].str.contains("SSD"))] = 1
df.
